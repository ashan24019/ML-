# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("Salary_dataset.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
plt.scatter(data.YearsExperience, data.Salary, color="red")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
x = np.array(data.YearsExperience)
x
# Out:
# array([ 1.2,  1.4,  1.6,  2.1,  2.3,  3. ,  3.1,  3.3,  3.3,  3.8,  4. ,
#         4.1,  4.1,  4.2,  4.6,  5. ,  5.2,  5.4,  6. ,  6.1,  6.9,  7.2,
#         8. ,  8.3,  8.8,  9.1,  9.6,  9.7, 10.4, 10.6])

# %%
y= np.array(data.Salary)
y
# Out:
# array([ 39344.,  46206.,  37732.,  43526.,  39892.,  56643.,  60151.,
#         54446.,  64446.,  57190.,  63219.,  55795.,  56958.,  57082.,
#         61112.,  67939.,  66030.,  83089.,  81364.,  93941.,  91739.,
#         98274., 101303., 113813., 109432., 105583., 116970., 112636.,
#        122392., 121873.])

# %%
model = LinearRegression()
model.fit(x.reshape(-1, 1), y)
# Out:
# LinearRegression()

# %%
new_yearsOfExperience = np.array([9]).reshape((-1, 1))

# %%
prediction = model.predict(new_yearsOfExperience)
prediction
# Out:
# array([109897.86485962])

# %%
plt.scatter(data.YearsExperience, data.Salary, color="red")
m,c = np.polyfit(x,y,1)
plt.plot(x, m*x + c, color="blue")

# %%
m
# Out:
# np.float64(9449.962321455077)

# %%
c
# Out:
# np.float64(24848.203966523204)

# %%
y_new = m*9 + c
y_new
# Out:
# np.float64(109897.8648596189)
